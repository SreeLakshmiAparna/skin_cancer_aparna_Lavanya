# %%
import pandas as pd
import cv2 
import numpy as np
import os 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\\sem_7\\Project\\archive\\HAM10000_metadata.csv")
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
df['image_id'][0]
# Out:
# 'ISIC_0027419'

# %%
dir="D:\sem_7\Project\\archive"
import pathlib
dir=pathlib.Path(dir)
dir
# Out:
# WindowsPath('D:/sem_7/Project/archive')

# %%
list(dir.glob('HAM10000_images_part_1/*'))
# Out:
# [WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024306.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024307.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024308.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024309.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024310.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024311.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024312.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024313.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024314.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024315.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024316.jpg'),
# ...

# %%
df['dx'].unique()
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %%
x=[]
x=df[df['dx']=='bkl']
v=x['image_id']
v
# Out:
# 0       ISIC_0027419
# 1       ISIC_0025030
# 2       ISIC_0026769
# 3       ISIC_0025661
# 4       ISIC_0031633
#             ...
# 3326    ISIC_0025366
# 7100    ISIC_0028977
# 9546    ISIC_0032655
# 9630    ISIC_0033620
# 9631    ISIC_0034040
# Name: image_id, Length: 1099, dtype: object

# %%
path_from_data="D:\sem_7\Project\\archive\\HAM10000_images_part_1"
path_to_dataset="D:\sem_7\Project\\aparna_Lavanya_project\\image_dataset\\vasc"

# %%
u=list(dir.glob('HAM10000_images_part_1/*'))
# Out:
# [WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024306.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024307.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024308.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024309.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024310.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024311.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024312.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024313.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024314.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024315.jpg'),
#  WindowsPath('D:/sem_7/Project/archive/ham10000_images_part_1/ISIC_0024316.jpg'),
# ...

# %%
img=cv2.imread(str(u[0]))

# %%
plt.imshow(img)

# %%
os.chdir(path_to_dataset)
print(len(os.listdir(path_to_dataset)))

# %%
len(v)
# Out:
# 1099

# %%
for i in v:
    print(i)
# Out:
# ISIC_0027419
# ISIC_0025030
# ISIC_0026769
# ISIC_0025661
# ISIC_0031633
# ISIC_0027850
# ISIC_0029176
# ISIC_0029068
# ISIC_0025837
# ISIC_0025209
# ISIC_0025276
# ISIC_0029396
# ISIC_0025984
# ISIC_0025767
# ISIC_0032417
# ISIC_0031326
# ISIC_0025915
# ISIC_0031029
# ISIC_0029836
# ISIC_0032129
# ISIC_0032343
# ISIC_0025033
# ISIC_0027310
# ISIC_0032128
# ISIC_0025937
# ISIC_0027828
# ISIC_0029291
# ISIC_0030698
# ISIC_0025567
# ISIC_0031753
# ISIC_0026835
# ISIC_0031159
# ISIC_0031017
# ISIC_0024981
# ISIC_0027815
# ISIC_0024324
# ISIC_0029559
# ISIC_0030661
# ISIC_0027053
# ISIC_0028560
# ISIC_0031650
# ISIC_0029161
# ISIC_0026273
# ISIC_0025076
# ISIC_0029687
# ISIC_0025642
# ISIC_0025819
# ISIC_0032013
# ISIC_0031691
# ISIC_0025419
# ISIC_0030105
# ISIC_0025016
# ISIC_0029147
# ISIC_0029301
# ISIC_0026637
# ISIC_0030377
# ISIC_0027960
# ISIC_0026955
# ISIC_0028052
# ISIC_0025286
# ISIC_0031468
# ISIC_0030926
# ISIC_0029288
# ISIC_0031008
# ISIC_0031495
# ISIC_0026104
# ...

# %%
for i in v:
    for j in u:
        if i in str(j):
            s=i+'.jpg'
            img=cv2.imread(str(j))
            cv2.imwrite(s,img)

# %%
path_from_data="D:\sem_7\Project\\archive\\HAM10000_images_part_2"
path_to_dataset="D:\sem_7\Project\\aparna_Lavanya_project\\image_dataset\\vasc"

# %%
u=list(dir.glob('HAM10000_images_part_2/*'))

# %%
for i in v:
    for j in u:
        if i in str(j):
            s=i+'.jpg'
            img=cv2.imread(str(j))
            cv2.imwrite(s,img)

# %%
print(len(os.listdir(path_to_dataset)))
# Out:
# 0

# %%
path_from_data="D:\sem_7\Project\\archive\\HAM10000_images_part_1"
path_to_dataset="D:\sem_7\Project\\archive\\nv"

# %%
x=[]
x=df[df['dx']=='nv']
v=x['image_id']
v
# Out:
# 64      ISIC_0024698
# 1210    ISIC_0024693
# 2976    ISIC_0032212
# 2977    ISIC_0025775
# 2978    ISIC_0029828
#             ...
# 9682    ISIC_0027924
# 9683    ISIC_0031547
# 9684    ISIC_0032221
# 9685    ISIC_0030693
# 9686    ISIC_0031649
# Name: image_id, Length: 6705, dtype: object

# %%
u=list(dir.glob('HAM10000_images_part_1/*'))

# %%
os.chdir(path_to_dataset)
print(len(os.listdir(path_to_dataset)))
# Out:
# 0

# %%
for i in v:
    for j in u:
        if i in str(j):
            s=i+'.jpg'
            img=cv2.imread(str(j))
            cv2.imwrite(s,img)

# %%
u=list(dir.glob('HAM10000_images_part_2/*'))

# %%
for i in v:
    for j in u:
        if i in str(j):
            s=i+'.jpg'
            img=cv2.imread(str(j))
            cv2.imwrite(s,img)

# %%
print(len(os.listdir(path_to_dataset)))
# Out:
# 6705

# %%
len(v)
# Out:
# 6705

# %%
path_from_data="D:\sem_7\Project\\archive\\HAM10000_images_part_1"
path_to_dataset="D:\sem_7\Project\\archive\\mel"

# %%
x=[]
x=df[df['dx']=='mel']
v=x['image_id']
v=list(v)

# %%
len(v)
# Out:
# 1113

# %%
u=list(dir.glob('HAM10000_images_part_1/*'))

# %%
os.chdir(path_to_dataset)
print(len(os.listdir(path_to_dataset)))
# Out:
# 952

# %%
type(v)
# Out:
# list

# %%
for i in v:
    for j in u:
        if i in str(j):
            s=i+'.jpg'
            img=cv2.imread(str(j))
            cv2.imwrite(s,img)

# %%
u=list(dir.glob('HAM10000_images_part_2/*'))

# %%
for i in v:
    for j in u:
        if i in str(j):
            s=i+'.jpg'
            img=cv2.imread(str(j))
            cv2.imwrite(s,img)

# %%
print(len(os.listdir(path_to_dataset)))
# Out:
# 1113

# %%
path_from_data="D:\sem_7\Project\\archive\\HAM10000_images_part_1"
path_to_dataset="D:\sem_7\Project\\archive\\df"

# %%
x=[]
x=df[df['dx']=='df']
v=x['image_id']
v=list(v)

# %%
len(v)
# Out:
# 115

# %%
u=list(dir.glob('HAM10000_images_part_1/*'))

# %%
os.chdir(path_to_dataset)
print(len(os.listdir(path_to_dataset)))
# Out:
# 0

# %%
for i in v:
    for j in u:
        if i in str(j):
            s=i+'.jpg'
            img=cv2.imread(str(j))
            cv2.imwrite(s,img)

# %%
u=list(dir.glob('HAM10000_images_part_2/*'))

# %%
path_from_data="D:\sem_7\Project\\archive\\HAM10000_images_part_1"
path_to_dataset="D:\sem_7\Project\\archive\\bcc"

# %%
x=[]
x=df[df['dx']=='bcc']
v=x['image_id']
v=list(v)

# %%
len(v)
# Out:
# 514

# %%
u=list(dir.glob('HAM10000_images_part_1/*'))

# %%
os.chdir(path_to_dataset)
print(len(os.listdir(path_to_dataset)))
# Out:
# 0

# %%
for i in v:
    for j in u:
        if i in str(j):
            s=i+'.jpg'
            img=cv2.imread(str(j))
            cv2.imwrite(s,img)

# %%
u=list(dir.glob('HAM10000_images_part_2/*'))

# %%
print(len(os.listdir(path_to_dataset)))
# Out:
# 514

# %%
path_from_data="D:\sem_7\Project\\archive\\HAM10000_images_part_1"
path_to_dataset="D:\sem_7\Project\\aparna_Lavanya_project\\image_dataset\\vasc"

# %%
u=list(dir.glob('HAM10000_images_part_1/*'))
